# %%
import psrchive
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Load Data

# %%
def read_file(file_path):
    a = psrchive.Archive_load(file_path)
    a.tscrunch()
    a.dedisperse()
    a.pscrunch()
    a.remove_baseline()
    data = a.get_data()
    
    # Get weights
    ww = np.array(a.get_weights(), dtype=bool)
    # Create array with only True with same shape as data
    wts = np.ones(data.shape, dtype=bool)
    
    # If True in ww, set to false in wts
    # Essentially, creates the opposite of ww
    wts[...,ww,:] = False
    
    # set all values in data with True in wts to nan
    mata = data.copy()
    mata[wts] = np.nan
    
    #Select only the arrays we are interested in
    matadata = mata[0,0,:]

    #Perform the normalisation from 0 to 1 on the y axis
    mata_normalized = (matadata - np.min(matadata))/(np.max(matadata) - np.min(matadata))
    
    return(mata_normalized)

# %%
file1 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean1.0000_0000.5chns'
file2 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean1.0001_0000.5chns'
file3 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean1.0002_0000.5chns'
file4 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean1.0003_0000.5chns'
file5 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean1.0004_0000.5chns'
file6 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean2.0000_0000.5chns'
file7 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean2.0001_0000.5chns'
file8 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean2.0002_0000.5chns'
file9 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean2.0003_0000.5chns'
file10 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean2.0004_0000.5chns'
file11 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean3.0000_0000.5chns'
file12 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean3.0001_0000.5chns'
file13 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean3.0002_0000.5chns'
file14 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean3.0003_0000.5chns'
file15 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean3.0004_0000.5chns'
file16 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean4.0000_0000.5chns'
file17 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean4.0001_0000.5chns'
file18 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean4.0002_0000.5chns'
file19 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean4.0003_0000.5chns'
file20 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean4.0004_0000.5chns'
file21 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean5.0000_0000.5chns'
file22 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean5.0001_0000.5chns'
file23 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean5.0002_0000.5chns'
file24 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean5.0003_0000.5chns'
file25 = '/srv/storage_11/galc/UBB/jtremblay/20240216/split/B0355+54_added_clean5.0004_0000.5chns'


data1 = read_file(file1)
data2 = read_file(file2)
data3 = read_file(file3)
data4 = read_file(file4)
data5 = read_file(file5)
data6 = read_file(file6)
data7 = read_file(file7)
data8 = read_file(file8)
data9 = read_file(file9)
data10 = read_file(file10)
data11 = read_file(file11)
data12 = read_file(file12)
data13 = read_file(file13)
data14 = read_file(file14)
data15 = read_file(file15)
data16 = read_file(file16)
data17 = read_file(file17)
data18 = read_file(file18)
data19 = read_file(file19)
data20 = read_file(file20)
data21 = read_file(file21)
data22 = read_file(file22)
data23 = read_file(file23)
data24 = read_file(file24)
data25 = read_file(file25)

#frequencies = [1376.667, 1488.374, 1618.461]
#profiles = [data1[0], data2[0], data3[0]]

freqs = [1376.667, 1488.374, 1618.461, 1731.443, 1917.878, 2011.774, 2133.299, 2264.951, 2365.457, 2513.430, 3090.375, \
        3320.216, 3504.385, 3800.744, 3995.058, 4165.897, 4453.967, 4666.801, 4888.926, 5096.802, 5308.416, 5448.806, \
        5606.037, 5746.470, 5899.499]

# %%
fig = plt.figure(figsize=(5, 15))  # Set figure size directly in the figure call

#Plot the normalized data
plt.plot(data1[0][500:650], "k")
plt.plot(data2[0][500:650] + 0.5, "k")
plt.plot(data3[0][500:650] + 1, "k")
plt.plot(data4[0][500:650] + 1.5, "k")
plt.plot(data5[0][500:650] + 2, "k")
plt.plot(data6[0][500:650] + 2.5, "k")
#plt.plot(data7[0][500:650] + 3, "k")
plt.plot(data8[0][500:650] + 3.5, "k")
plt.plot(data9[0][500:650] + 4, "k")
#plt.plot(data10[0][500:650] + 4.5, "k")
plt.plot(data11[0][500:650] + 5, "k")
plt.plot(data12[0][500:650] + 5.5, "k")
plt.plot(data13[0][500:650] + 6, "k")
plt.plot(data14[0][500:650] + 6.5, "k")
plt.plot(data15[0][500:650] + 7, "k")
plt.plot(data16[0][500:650] + 7.5, "k")
plt.plot(data17[0][500:650] + 8, "k")
plt.plot(data18[0][500:650] + 8.5, "k")
plt.plot(data19[0][500:650] + 9, "k")
plt.plot(data20[0][500:650] + 9.5, "k")
plt.plot(data21[0][500:650] + 10, "k")
plt.plot(data22[0][500:650] + 10.5, "k")
plt.plot(data23[0][500:650] + 11, "k")
plt.plot(data24[0][500:650] + 11.5, "k")
plt.plot(data25[0][500:650] + 12, "k")

tempdata = data1[0][500:650]
lineloc = np.argmax(tempdata)
#plt.axvline(x=lineloc, color='b', linestyle='--', linewidth=0.75, label='Loc of Peak1')
plt.plot([lineloc, lineloc], [0, 13.1], 'b--', linewidth=0.75, label='Location of Peak at 1376 MHz')

plt.yticks([0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10, 10.5, 11, 11.5, 12], freqs)
# Hide the x ticks
plt.xticks([])

plt.title('B0355+54')
#plt.xlabel('Pulse Phase [bins]')
plt.ylabel('Frequency [MHz]')
plt.legend()
plt.show()
